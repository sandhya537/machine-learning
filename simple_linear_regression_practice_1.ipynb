# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhya537/machine-learning/blob/main/simple_linear_regression_practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3a787776-eb3a-4aca-954f-0a3576460b5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a787776-eb3a-4aca-954f-0a3576460b5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#----------------------    loading dataset   --------------------------------------

import pandas as pd
df=pd.read_csv('student_scores.csv')
print(df.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#--------------------------- scatter plotting  -----------------------------------------

import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('student_scores.csv')
df.plot(x='Hours',y='Scores',style='o')
plt.xlabel('hours studied')
plt.ylabel('scores percentages')
plt.title('hours vs scores')
plt.show()

# %%
#-------------------   using iloc   -----------------------------------

import pandas as pd
df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values
print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %%
#--------------     testing training  -------------------------------------------

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

print('x_train:',x_train)
print('x_test:',x_test)
print('y_train:',y_train)
print('y_test:',y_test)
# Out:
# x_train: [[6.9]
#  [1.1]
#  [5.1]
#  [7.7]
#  [3.3]
#  [8.3]
#  [9.2]
#  [6.1]
#  [3.5]
#  [2.7]
#  [5.5]
#  [2.7]
#  [8.5]
#  [2.5]
#  [4.8]
#  [8.9]
#  [4.5]]
# x_test: [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]]
# y_train: [76 17 47 85 42 81 88 67 30 25 60 30 75 21 54 95 41]
# y_test: [20 27 69 30 62 35 24 86]

# %%
#-------------------      model training       ----------------------------------

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

print('model trained')
# Out:
# model trained

# %%
#--------------------      finding intercept    -------------------------------------

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

print(reg.intercept_)
# Out:
# 2.3708153823418883

# %%
#----------------     finding coef   -------------------------------------------

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

print(reg.coef_)
# Out:
# [9.78856669]

# %%
#---------------------     prediction    -------------------------------------------

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

y_prd=reg.predict(x_test)
print(y_prd)
# Out:
# [17.05366541 33.69422878 74.80620886 26.8422321  60.12335883 39.56736879
#  20.96909209 78.72163554]

# %%
#--------------- prediction of all ----------------------------------------------

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

y_prd=reg.predict(x_test)

df=pd.DataFrame({'actual':y_test.flatten(),'predicted':y_prd.flatten()})
print(df)
#  or

# d={'actual':y_test,'predicted':y_prd}
# df=pd.DataFrame(d)
#print(df)
# Out:
#    actual  predicted
# 0      20  17.053665
# 1      27  33.694229
# 2      69  74.806209
# 3      30  26.842232
# 4      62  60.123359
# 5      35  39.567369
# 6      24  20.969092
# 7      86  78.721636

# %%
#------------------      mae,mse,rmse     =========================================

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn import metrics
df=pd.read_csv('student_scores.csv')
x=df.iloc[:,:-1].values
y=df.iloc[:,1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

reg=LinearRegression()
reg.fit(x_train,y_train)

y_prd=reg.predict(x_test)

mae=metrics.mean_absolute_error(y_test,y_prd)
mse=metrics.mean_squared_error(y_test,y_prd)
rmse=metrics.mean_squared_error(y_test,y_prd)
print('mean absolute error:',mae)
print('mean squared error:',mse)
print('root mean squared error:',rmse)
# Out:
# mean absolute error: 4.419727808027651
# mean squared error: 22.965097212700428
# root mean squared error: 22.965097212700428
